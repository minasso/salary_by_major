# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 8471-B1A1
#
#  Directory of C:\Users\Andrew\Desktop\Coding Projects\college-salaries
#
# 06/29/2019  06:15 PM    <DIR>          .
# 06/29/2019  06:15 PM    <DIR>          ..
# 06/28/2019  10:36 PM    <DIR>          .ipynb_checkpoints
# 04/29/2017  11:48 AM             5,179 degrees-that-pay-back.csv
# 04/29/2017  11:48 AM            31,434 salaries-by-college-type.csv
# 04/29/2017  11:48 AM            37,609 salaries-by-region.csv
# 06/29/2019  06:15 PM           504,468 Salary vs Major.ipynb
#                4 File(s)        578,690 bytes
#                3 Dir(s)  19,918,487,552 bytes free

# %%
file1 = 'degrees-that-pay-back.csv'
file2 = 'salaries-by-college-type.csv'
file3 = 'salaries-by-region.csv'

# %%
df = pd.read_csv(file1)

# %%
df
# Out:
#                      Undergraduate Major Starting Median Salary  \
# 0                             Accounting             $46,000.00
# 1                  Aerospace Engineering             $57,700.00
# 2                            Agriculture             $42,600.00
# 3                           Anthropology             $36,800.00
# 4                           Architecture             $41,600.00
# 5                            Art History             $35,800.00
# 6                                Biology             $38,800.00
# 7                    Business Management             $43,000.00
# 8                   Chemical Engineering             $63,200.00
# 9                              Chemistry             $42,600.00
# 10                     Civil Engineering             $53,900.00
# 11                        Communications             $38,100.00
# 12                  Computer Engineering             $61,400.00
# 13                      Computer Science             $55,900.00
# ...

# %% [markdown]
# Fix data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
# Undergraduate Major                                  50 non-null object
# Starting Median Salary                               50 non-null object
# Mid-Career Median Salary                             50 non-null object
# Percent change from Starting to Mid-Career Salary    50 non-null float64
# Mid-Career 10th Percentile Salary                    50 non-null object
# Mid-Career 25th Percentile Salary                    50 non-null object
# Mid-Career 75th Percentile Salary                    50 non-null object
# Mid-Career 90th Percentile Salary                    50 non-null object
# dtypes: float64(1), object(7)
# memory usage: 3.2+ KB

# %%
cols = df.columns

# %%
for col in cols:
    print(col) 
    try:
        df[col] = df[col].apply(lambda x: x.replace('$','').replace(',',''))
        df[col] = pd.to_numeric(df[col])
    except:
        pass
# Out:
# Undergraduate Major
# Starting Median Salary
# Mid-Career Median Salary
# Percent change from Starting to Mid-Career Salary
# Mid-Career 10th Percentile Salary
# Mid-Career 25th Percentile Salary
# Mid-Career 75th Percentile Salary
# Mid-Career 90th Percentile Salary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
# Undergraduate Major                                  50 non-null object
# Starting Median Salary                               50 non-null float64
# Mid-Career Median Salary                             50 non-null float64
# Percent change from Starting to Mid-Career Salary    50 non-null float64
# Mid-Career 10th Percentile Salary                    50 non-null float64
# Mid-Career 25th Percentile Salary                    50 non-null float64
# Mid-Career 75th Percentile Salary                    50 non-null float64
# Mid-Career 90th Percentile Salary                    50 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# Find highest starting salaries

# %%
top_10_start = df.sort_values('Starting Median Salary',ascending=False).head(10)

# %%
top_10_med = df.sort_values('Mid-Career Median Salary',ascending=False).head(10)

# %%
top_10_pct = df.sort_values('Percent change from Starting to Mid-Career Salary',ascending=False).head(10)

# %% [markdown]
# Start doing some plotting

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12,6

# %%
import seaborn as sns

# %%
sns.set()

# %%
top_10_med
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 8     Chemical Engineering                 63200.0                  107000.0
# 12    Computer Engineering                 61400.0                  105000.0
# 19  Electrical Engineering                 60900.0                  103000.0
# 1    Aerospace Engineering                 57700.0                  101000.0
# 17               Economics                 50100.0                   98600.0
# 44                 Physics                 50300.0                   97300.0
# 13        Computer Science                 55900.0                   95500.0
# 30  Industrial Engineering                 57700.0                   94700.0
# 38  Mechanical Engineering                 57900.0                   93600.0
# 37                    Math                 45400.0                   92400.0
#
#     Percent change from Starting to Mid-Career Salary  \
# 8                                                69.3
# ...

# %%
sns.barplot(x='Undergraduate Major',y='Starting Median Salary',data = top_10_start)
plt.xticks(rotation=20)
plt.title('Starting Median Salary by Undergraduate Major')
# Out:
# Text(0.5, 1.0, 'Starting Median Salary by Undergraduate Major')

# %%
sns.barplot(x=top_10_med['Undergraduate Major'],y=top_10_med['Mid-Career Median Salary'])
plt.xticks(rotation=25)
plt.title('Mid-Career Median Salary by Undergraduate Major')
# Out:
# Text(0.5, 1.0, 'Mid-Career Median Salary by Undergraduate Major')

# %%
sns.barplot(x='Undergraduate Major',y='Percent change from Starting to Mid-Career Salary',data = top_10_pct)
plt.xticks(rotation=20)
plt.title('Percent change from Starting to Mid-Career Salary by Undergraduate Major')
# Out:
# Text(0.5, 1.0, 'Percent change from Starting to Mid-Career Salary by Undergraduate Major')

# %% [markdown]
# Try to create a bar graph of all college majors by switching the axes

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %% [markdown]
# Change x-ticks to every 5000

# %%
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.xticks(np.arange(0,80000,5000))
sns.barplot(ax = ax, data = df.sort_values('Starting Median Salary',ascending=False),x='Starting Median Salary',y='Undergraduate Major')

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(ax = ax, data = df.sort_values('Mid-Career Median Salary',ascending=False),x='Mid-Career Median Salary',y='Undergraduate Major')

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.xticks(np.arange(0,105,10))
sns.barplot(ax = ax, data = df.sort_values('Percent change from Starting to Mid-Career Salary',ascending=False),x='Percent change from Starting to Mid-Career Salary',y='Undergraduate Major')

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...
